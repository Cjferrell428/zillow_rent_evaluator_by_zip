# %% [markdown]
# ## Base Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ## Notebook and Request Header Settings

# %%
# set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %% [markdown]
# ## Helper functions for Creating Soups

# %%
def build_soups(url):
    """
    Builds BeautifulSoup objects for each page of the Zillow search results.
    """
    response = requests.get(url, headers=req_headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %% [markdown]
# ## Grab/Create all Soups

# %%
base_url = 'https://www.zillow.com/homes/for_rent/'
page_max_range = 10
city = 'Omaha'
soups = []

for i in range(1, page_max_range):
    url = f'{base_url}{city}/{str(i)}_p/'
    soups.append(build_soups(url))

# %% [markdown]
# ## Grab Data from All Soups and Create Huge Dataframe

# %%
def grab_soup_data(soups):
    """
    Grabs all the data from the soup objects and puts it into a list.
    """
    soup_data = []
    for soup in soups:
        # all for loops are pulling the specified variable using beautiful soup and inserting into said variable
        df = pd.DataFrame(
            columns=['prices', 'address', 'beds', 'sqft', 'links'])

        for i in soup:
            address = soup.find_all(class_='list-card-addr')
            price = list(soup.find_all(class_='list-card-price'))
            beds = list(soup.find_all("ul",  class_="list-card-details"))
            sqft = list(soup.find_all("ul",  class_="list-card-details"))
            details = soup.find_all('div', {'class': 'list-card-details'})
            home_type = soup.find_all('div', {'class': 'list-card-footer'})
            last_updated = soup.find_all('div', {'class': 'list-card-top'})
            brokerage = list(soup.find_all(
                class_='list-card-brokerage list-card-img-overlay', text=True))
            link = soup.find_all(class_='list-card-link')

            # create dataframe columns out of variables
            df['prices'] = price
            df['address'] = address
            df['beds'] = beds
            df['sqft'] = sqft

        # create empty url list
        urls = []

        # loop through url, pull the href and strip out the address tag
        for link in soup.find_all("article"):
            href = link.find('a', class_="list-card-link")
            if href:
                addresses = href.get('href')
                urls.append(addresses)

        # import urls into a links column
        df['links'] = urls
        df['links'] = df['links'].astype('str')

        # remove html tags
        df['links'] = df['links'].replace(
            '<a class="list-card-link" href="', ' ', regex=True)
        df['links'] = df['links'].replace(
            '" tabindex="0"></a>', ' ', regex=True)
        soup_data.append(df)
    return soup_data

df = pd.concat(grab_soup_data(soups), ignore_index=True)

# %% [markdown]
# ## Cleanup the Huge Dataframe

# %%
#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')
df['sqft'] = df['sqft'].astype('str')

#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')

#need to figure out correct html to add to this code from zillow browser
#remove html tags from beds column
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].str.replace(r'\D', ' ', regex=True)
df['sqft'] = df['sqft'].replace('Studio</li><li>', '0 ', regex=True)
df['sqft'] = df['sqft'].str.replace(r'\D', ' ', regex=True)


#split beds column into beds, bath and sqft
#will need to concatenate and split up columns after everything is pulled into data frame

#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

#drop nulls
df = df[(df['prices'] != '') & (df['prices']!= ' ')]

#convert column to float
df['prices'] = df['prices'].astype('float')


#remove spaces from link column
df['links'] = df.links.str.replace(' ','')

print('The column datatypes are:')
print(df.dtypes)
print('The dataframe shape is:', df.shape)

#re arrange the data frame and include sq  - make sure the dataframe has correct vallues
#will need to split zip code into its own column
#find out how to extract zillow html and put it into notebook

df
# Out:
# The column datatypes are:
# prices     float64
# address     object
# beds        object
# sqft        object
# links       object
# dtype: object
# The dataframe shape is: (81, 5)
# /Users/n8patteson/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   if sys.path[0] == '':
#      prices                                            address                                               beds                                               sqft                                              links
# 0   11501.0               Edge 204 | 3030 S 202nd Ct Omaha NE                                               1 ...                                              1 ...                       /b/edge-204-omaha-ne-BvqCQx/
# 1    1800.0                   4958 S 167th Ave Omaha NE 68135                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/4958-S-167t...
# 2    9501.0      Whispering Hills | 2510 N 109th Plz Omaha NE                                               1 ...                                              1 ...               /b/whispering-hills-omaha-ne-5YyCRV/
# 3    1110.0               The Conrad | 3601 Jones St Omaha NE                                               1 ...                                              1 ...                     /b/the-conrad-omaha-ne-9WHB3w/
# 4    8401.0   Apple Creek Apartments | 14010 Dorcas Plz Oma...                                              1 ...                                              1 ...         /b/apple-creek-apartments-omaha-ne-5Yy8Pq/
# 5     943.0        Legacy Commons | 17011 Wright Plz Omaha NE                                               1 ...                                              1 ...                 /b/legacy-commons-omaha-ne-5Xrv3W/
# 6    9451.0   Eagle Run Apartments | 3203 N 121st Plz Omaha...                                                                                                                 /b/eagle-run-apartments-omaha-ne-5hJ8zn/
# 7    7001.0                The Fairway | 10025 S Plz Omaha NE                                               86...                                              86...                    /b/the-fairway-omaha-ne-BDTmj4/
# 8   10301.0   Tiburon View Apartments | 16895 Oakmont Dr Om...                                              1 ...                                              1 ...        /b/tiburon-view-apartments-omaha-ne-5Xt4XN/
# 9    1210.0              617 S 31st St APT 401 Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/617-S-31st-...
# 10   9651.0   Park Place Apartments | 12115 William Plz Oma...                                              1 ...                                              1 ...          /b/park-place-apartments-omaha-ne-5Yy8PJ/
# 11  10151.0   Autumn Grove Apartments | 5380 S 156th St Oma...                                              1 ...                                              1 ...        /b/autumn-grove-apartments-omaha-ne-BKzzfc/
# 12   7501.0         Kensington Tower | 505 S 16th St Omaha NE                                                                                                                      /b/kensington-tower-omaha-ne-5XnQKq/
# 13   8101.0   Thomasville by Broadmoor | 5820 S 99th St Oma...                                              99...                                              99...       /b/thomasville-by-broadmoor-omaha-ne-5XtP7S/
# 14   1500.0                     2510 N 64th St Omaha NE 68104                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2510-N-64th...
# 15   8551.0      The Bank Apartments | 206 S 19th St Omaha NE                                               1 ...                                              1 ...            /b/the-bank-apartments-omaha-ne-5Xt4ZT/
# 16   9951.0                 The Wire | 100 S 19th St Omaha NE                                               1 ...                                              1 ...                       /b/the-wire-omaha-ne-5hJ8zs/
# 17   1600.0                   2329 N 143rd Ave Omaha NE 68164                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2329-N-143r...
# 18   8251.0     Place 72 Apartments | 2506 S 72nd Ct Omaha NE                                                                                                                   /b/place-72-apartments-omaha-ne-5bkqPN/
# 19   1600.0                 17971 Oak Plz #213 Omaha NE 68130                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/17971-Oak-P...
# 20  10451.0   Wyndham Villas by Broadmoor | 9310 Western Av...                                              1 ...                                              1 ...    /b/wyndham-villas-by-broadmoor-omaha-ne-5Yy8NG/
# 21   9801.0   Breckenridge Apartments | 15950 Wright Plz Om...                                              1 ...                                              1 ...        /b/breckenridge-apartments-omaha-ne-5XrbRL/
# 22  11301.0   Crown Park by Broadmoor | 7930 Elm Plz Omaha NE                                               1 ...                                              1 ...        /b/crown-park-by-broadmoor-omaha-ne-5Xt8Tz/
# 23    900.0              Echo Park | 7457 S 146th St Omaha NE                                               1 ...                                              1 ...                      /b/echo-park-omaha-ne-C38Jnm/
# 24    875.0             The Mill | 6152 Military Ave Omaha NE                                               97...                                              97...                       /b/the-mill-omaha-ne-9JdDcy/
# 25    960.0         Old Market Lofts | 1011 Jones St Omaha NE                                               1 ...                                              1 ...               /b/old-market-lofts-omaha-ne-5Yy8My/
# 26  10071.0          The Falgrove | 5410 S 111th Plz Omaha NE                                               1 ...                                              1 ...                   /b/the-falgrove-omaha-ne-5YxbCg/
# 27    695.0                    833 Park Ave #1 Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/833-Park-Av...
# 28   1800.0                      19362 Laci St Omaha NE 68135                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/19362-Laci-...
# 29   1500.0                   15920 Martha Cir Omaha NE 68130                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/15920-Marth...
# 30    800.0                 2323 Village Ct #2 Omaha NE 68144                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2323-Villag...
# 31   1600.0               9525 Binney St #9525 Omaha NE 68134                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/9525-Binney...
# 32   1950.0                   2127 N 167th Cir Omaha NE 68116                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2127-N-167t...
# 33   1950.0                       105 S 9th St Omaha NE 68102                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/105-S-9th-S...
# 34   1300.0                     3336 N 53rd St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/3336-N-53rd...
# 35   1705.0                    14715 Locust St Omaha NE 68116                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/14715-Locus...
# 36   2000.0                      525 N 74th St Omaha NE 68114                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/525-N-74th-...
# 37   1600.0                   2273 S 135th Cir Omaha NE 68144                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2273-S-135t...
# 38    870.0                      605 S 37th St Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/605-S-37th-...
# 39   1295.0            3111 S 22nd St #2841171 Omaha NE 68108                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/3111-S-22nd...
# 40    750.0                       4816 Cass St Omaha NE 68132                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/4816-Cass-S...
# 41   2500.0                      404 N 40th St Omaha NE 68131                                              5  ...                                             5  ...  https://www.zillow.com/homedetails/404-N-40th-...
# 42   1800.0                    6718 S 152nd St Omaha NE 68137                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/6718-S-152n...
# 43  12311.0   CUE at Aksarben Village | 2110 S 64th Ave Oma...                                              1 ...                                              1 ...        /b/cue-at-aksarben-village-omaha-ne-B64yYb/
# 44    775.0                 535 S 37th St #205 Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/535-S-37th-...
# 45   1100.0                     5112 N 48th St Omaha NE 68104                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/5112-N-48th...
# 46   1200.0                     2327 S 47th St Omaha NE 68106                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2327-S-47th...
# 47   1200.0                     2325 S 47th St Omaha NE 68106                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2325-S-47th...
# 48   2150.0                    1522 S 139th St Omaha NE 68144                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1522-S-139t...
# 49    900.0                      4305 Miami St Omaha NE 68111                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/4305-Miami-...
# 50    875.0             300 S 16th St APT 1207 Omaha NE 68102                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/300-S-16th-...
# 51    670.0                  8919 Burt St #105 Omaha NE 68114                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/8919-Burt-S...
# 52   1825.0                  12911 Chandler St Omaha NE 68138                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/12911-Chand...
# 53   1500.0                   2862 Whitmore St Omaha NE 68112                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2862-Whitmo...
# 54   1650.0               15613 Cottonwood Ave Omaha NE 68136                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/15613-Cotto...
# 55    750.0                 1618 S 32nd Ave #4 Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1618-S-32nd...
# 56   1795.0                  14461 Saratoga St Omaha NE 68116                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/14461-Sarat...
# 57   1450.0                     1615 S 60th St Omaha NE 68106                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1615-S-60th...
# 58    750.0                 9036 Ohio St APT 4 Omaha NE 68134                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/9036-Ohio-S...
# 59    750.0               1012 N 45th St APT 2 Omaha NE 68132                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1012-N-45th...
# 60   1300.0                     2146 S 47th St Omaha NE 68106                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2146-S-47th...
# 61   2000.0                   17477 Riviera Dr Omaha NE 68136                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/17477-Rivie...
# 62   1300.0                     1101 S 63rd St Omaha NE 68106                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/1101-S-63rd...
# 63   1700.0                   11331 Martin Ave Omaha NE 68164                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/11331-Marti...
# 64   1700.0                    5455 S 194th St Omaha NE 68135                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/5455-S-194t...
# 65   1050.0                      13122 N St #8 Omaha NE 68137                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/13122-N-St-...
# 66   1200.0                     1317 S 12th St Omaha NE 68108                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1317-S-12th...
# 67   2195.0                     15230 Sharp St Omaha NE 68137                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/15230-Sharp...
# 68   1175.0                    3508 N 47th Ave Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/3508-N-47th...
# 69    925.0                      7305 Ames Cir Omaha NE 68134                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/7305-Ames-C...
# 70   1795.0                      525 S 31st St Omaha NE 68105                                              4  ...                                             4  ...  https://www.zillow.com/homedetails/525-S-31st-...
# 71    800.0                204 Paxton Ct APT 5 Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/204-Paxton-...
# 72   1850.0               105 S 9th St APT 512 Omaha NE 68102                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/105-S-9th-S...
# 73    800.0                     1308 N 40th St Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1308-N-40th...
# 74   1600.0                   5306 S 104th Ave Omaha NE 68127                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/5306-S-104t...
# 75    575.0             2008 NW Radial Hwy #12 Omaha NE 68104                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/2008-NW-Rad...
# 76   1950.0                      16509 Weir St Omaha NE 68135                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/16509-Weir-...
# 77    575.0                     135 N 43rd Ave Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/135-N-43rd-...
# 78   1795.0                      17828 Edna St Omaha NE 68136                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/17828-Edna-...
# 79   1250.0                     1615 N 58th St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1615-N-58th...
# 80   1150.0                     213 S 26th Ave Omaha NE 68131                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/213-S-26th-...
