# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
#create url variables for each zillow page
with requests.Session() as s:
    city = 'Omaha/' 
    
    url = 'https://www.zillow.com/homes/for_rent/'+city
    url2 = 'https://www.zillow.com/homes/for_rent/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_rent/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_rent/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_rent/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_rent/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_rent/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_rent/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_rent/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_rent/'+city+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# %%
#create the first two dataframes
df = pd.DataFrame()
df1 = pd.DataFrame()

#all for loops are pulling the specified variable using beautiful soup and inserting into said variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul",  class_="list-card-details"))
    sqft = list(soup.find_all("ul",  class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds
    df['sqft'] = sqft
    

#create empty url list
urls = []

# %%
#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df['links'] = urls
df['links'] = df['links'].astype('str')

#remove html tags
df['links'] = df['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)


for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df1['prices'] = price1
    df1['address'] = address1
    df1['beds'] = beds1
    df1['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

#remove html tags
df1['links'] = df1['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df1['links'] = df1['links'].replace('" tabindex="0"></a>', ' ', regex=True)

#append first two dataframes
df = df.append(df1, ignore_index = True) 

#create empty dataframes
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()

for i in soup2:
    soup = soup2
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul",  class_="list-card-details"))
    sqft = list(soup.find_all("ul",  class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df2['prices'] = price
    df2['address'] = address1
    df2['beds'] = beds
    df2['sqft'] = sqft

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

#remove html tags
df2['links'] = df2['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df2['links'] = df2['links'].replace('" tabindex="0"></a>', ' ', regex=True)

    
for i in soup3:
    soup = soup3
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df3['prices'] = price1
    df3['address'] = address1
    df3['beds'] = beds
    df3['sqft'] = sqft

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

#remove html tags
df3['links'] = df3['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df3['links'] = df3['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup4:
    soup = soup4
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df4['prices'] = price1
    df4['address'] = address1
    df4['beds'] = beds
    df4['sqft'] = sqft1
    
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup4.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df4['links'] = urls
df4['links'] = df4['links'].astype('str')

#remove html tags
df4['links'] = df4['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df4['links'] = df4['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup5:
    soup = soup5
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df5['prices'] = price1
    df5['address'] = address1
    df5['beds'] = beds
    df5['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup5.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df5['links'] = urls
df5['links'] = df5['links'].astype('str')

#remove html tags
df5['links'] = df5['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df5['links'] = df5['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup6:
    soup = soup6
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df6['prices'] = price1
    df6['address'] = address1
    df6['beds'] = beds
    df6['sqft'] = sqft1
    
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup6.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df6['links'] = urls
df6['links'] = df6['links'].astype('str')

#remove html tags
df6['links'] = df6['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df6['links'] = df6['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup7:
    soup = soup7
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df7['prices'] = price1
    df7['address'] = address1
    df7['beds'] = beds
    df7['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup7.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df7['links'] = urls
df7['links'] = df7['links'].astype('str')

#remove html tags
df7['links'] = df7['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df7['links'] = df7['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup8:
    soup = soup8
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df8['prices'] = price1
    df8['address'] = address1
    df8['beds'] = beds
    df8['sqft'] = sqft1
    
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup8.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df8['links'] = urls
df8['links'] = df8['links'].astype('str')

#remove html tags
df8['links'] = df8['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df8['links'] = df8['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup9:
    soup = soup9
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df9['prices'] = price1
    df9['address'] = address1
    df9['beds'] = beds
    df9['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup9.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df9['links'] = urls
df9['links'] = df9['links'].astype('str')

#remove html tags
df9['links'] = df9['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df9['links'] = df9['links'].replace('" tabindex="0"></a>', ' ', regex=True)

df = df.append(df2, ignore_index = True) 
df = df.append(df3, ignore_index = True) 
df = df.append(df4, ignore_index = True) 
df = df.append(df5, ignore_index = True) 
df = df.append(df6, ignore_index = True) 
df = df.append(df7, ignore_index = True) 
df = df.append(df8, ignore_index = True) 
df = df.append(df9, ignore_index = True) 

#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')
df['sqft'] = df['sqft'].astype('str')

#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')

#need to figure out correct html to add to this code from zillow browser
#remove html tags from beds column
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].str.replace(r'\D', ' ', regex=True)
df['sqft'] = df['sqft'].replace('Studio</li><li>', '0 ', regex=True)
df['sqft'] = df['sqft'].str.replace(r'\D', ' ', regex=True)


#split beds column into beds, bath and sqft
#will need to concatenate and split up columns after everything is pulled into data frame

#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

#drop nulls
df = df[(df['prices'] != '') & (df['prices']!= ' ')]

#convert column to float
df['prices'] = df['prices'].astype('float')


#remove spaces from link column
df['links'] = df.links.str.replace(' ','')

print('The column datatypes are:')
print(df.dtypes)
print('The dataframe shape is:', df.shape)

#re arrange the data frame and include sq  - make sure the dataframe has correct vallues
#will need to split zip code into its own column
#find out how to extract zillow html and put it into notebook

df
# Out:
# The column datatypes are:
# prices     float64
# address     object
# beds        object
# sqft        object
# links       object
# dtype: object
# The dataframe shape is: (90, 5)
# /Users/n8patteson/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:374: FutureWarning: The default value of regex will change from True to False in a future version.
#      prices                                            address                                               beds                                               sqft                                              links
# 0    1600.0                   2329 N 143rd Ave Omaha NE 68164                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2329-N-143r...
# 1     970.0   Broadmoor at Aksarben Village | 2225 S 64th P...                                              1 ...                                              1 ...  /b/broadmoor-at-aksarben-village-omaha-ne-5XtPhk/
# 2    1125.0           The Duke Omaha | 201 N 46th St Omaha NE                                               1 ...                                              1 ...                 /b/the-duke-omaha-omaha-ne-BLzSVn/
# 3    1110.0               The Conrad | 3601 Jones St Omaha NE                                               1 ...                                              1 ...                     /b/the-conrad-omaha-ne-9WHB3w/
# 4    9541.0        Briar Hills | 17010 Hawthorne Plz Omaha NE                                               1 ...                                              1 ...                    /b/briar-hills-omaha-ne-5Xs6sD/
# 5    2493.0            909 Capitol Ave APT 401 Omaha NE 68102                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/909-Capitol...
# 6    9951.0   Wyndham Hill by Broadmoor | 9226 Burt St Omah...                                              1 ...                                              1 ...      /b/wyndham-hill-by-broadmoor-omaha-ne-5XtP4L/
# 7    1250.0                 3412 Dodge St #106 Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/3412-Dodge-...
# 8   15002.0   Terrace Garden Townhomes | 10100 Grand Plz Om...                                                                                                             /b/terrace-garden-townhomes-omaha-ne-5XjCBP/
# 9     980.0               7515 Howard St #1106 Omaha NE 68114                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/7515-Howard...
# 10    850.0                 1427 1/2 S 14th St Omaha NE 68108                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/1427-1-2-S-...
# 11   1210.0              617 S 31st St APT 401 Omaha NE 68105                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/617-S-31st-...
# 12   9651.0   Park Place Apartments | 12115 William Plz Oma...                                              1 ...                                              1 ...          /b/park-place-apartments-omaha-ne-5Yy8PJ/
# 13  10131.0   Autumn Grove Apartments | 5380 S 156th St Oma...                                              1 ...                                              1 ...        /b/autumn-grove-apartments-omaha-ne-BKzzfc/
# 14   7501.0         Kensington Tower | 505 S 16th St Omaha NE                                              2  ...                                             2  ...               /b/kensington-tower-omaha-ne-5XnQKq/
# 15   8551.0      The Bank Apartments | 206 S 19th St Omaha NE                                               1 ...                                              1 ...            /b/the-bank-apartments-omaha-ne-5Xt4ZT/
# 16  11251.0   Midtown Crossing Apartments | 233 S 33rd St O...                                             1  ...                                             1  ...    /b/midtown-crossing-apartments-omaha-ne-5Xt4dv/
# 17   9951.0                 The Wire | 100 S 19th St Omaha NE                                                                                                                              /b/the-wire-omaha-ne-5hJ8zs/
# 18   9751.0               7515 Howard St #1106 Omaha NE 68114                                                                                                                /b/skinner-macaroni-lofts-omaha-ne-5YMgV9/
# 19   9701.0                 1427 1/2 S 14th St Omaha NE 68108                                               1 ...                                              1 ...                   /b/torrey-pines-omaha-ne-5Xq3Sr/
# 20   1100.0              617 S 31st St APT 401 Omaha NE 68105                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/5350-N-44th...
# 21   1350.0   Park Place Apartments | 12115 William Plz Oma...                                             3  ...                                             3  ...  https://www.zillow.com/homedetails/6311-Sahler...
# 22    695.0   Autumn Grove Apartments | 5380 S 156th St Oma...                                             1  ...                                             1  ...  https://www.zillow.com/homedetails/833-Park-Av...
# 23   1500.0         Kensington Tower | 505 S 16th St Omaha NE                                              4  ...                                             4  ...  https://www.zillow.com/homedetails/6110-Lafaye...
# 24   9501.0      The Bank Apartments | 206 S 19th St Omaha NE                                               1 ...                                              1 ...               /b/whispering-hills-omaha-ne-5YyCRV/
# 25    875.0   Midtown Crossing Apartments | 233 S 33rd St O...                                              1 ...                                              1 ...         /b/vantage-at-stone-creek-omaha-ne-BMSy29/
# 26    815.0                 The Wire | 100 S 19th St Omaha NE                                               1 ...                                              1 ...              /b/1415-%40-the-yard-omaha-ne-B6cfn4/
# 27   1295.0                   2878 Newport Ave Omaha NE 68112                                                                                                         https://www.zillow.com/homedetails/2878-Newpor...
# 28    650.0              8826 Miami St APT 302 Omaha NE 68134                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/8826-Miami-...
# 29    425.0              2205 Jones St APT 206 Omaha NE 68102                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2205-Jones-...
# 30    625.0                 3027 Chicago St #3 Omaha NE 68131                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/3027-Chicag...
# 31   6251.0        2917 Jackson St | 2917 Jackson St Omaha NE                                              1  ...                                             1  ...                /b/2917-jackson-st-omaha-ne-5j8WfX/
# 32   6751.0   4725 &amp; 4730 Cass St. | 4725 &amp; 4730 Ca...                                             4  ...                                             4  ...         /b/4725-%26-4730-cass-st.-omaha-ne-BgNw3F/
# 33   1200.0              3024 Pacific St APT 3 Omaha NE 68105                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/3024-Pacifi...
# 34   1700.0                   16404 Camden Ave Omaha NE 68116                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/16404-Camde...
# 35   1700.0                      19632 Laci St Omaha NE 68135                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/19632-Laci-...
# 36    895.0                 2006 NW Radial Hwy Omaha NE 68104                                                                                                 2  ...  https://www.zillow.com/homedetails/2006-NW-Rad...
# 37   1095.0                    1519 S 25th Ave Omaha NE 68105                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/1519-S-25th...
# 38   1175.0                   7069 Franklin St Omaha NE 68104                                              3  ...                                             2  ...  https://www.zillow.com/homedetails/7069-Frankl...
# 39   6501.0   10808 Oakbrook Circle | 10808 Oakbrook Cir Om...                                             3  ...                                              74...          /b/10808-oakbrook-circle-omaha-ne-5hJ925/
# 40    595.0              1825 NW Radial Hwy #6 Omaha NE 68104                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1825-NW-Rad...
# 41   2050.0                    6111 S 188th St Omaha NE 68135                                              4  ...                                             3  ...  https://www.zillow.com/homedetails/6111-S-188t...
# 42    695.0                  2607 N 93rd St #1 Omaha NE 68134                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/2607-N-93rd...
# 43  11952.0                          1012 Douglas St Omaha NE                                               1 ...                                                       /b/riley-building-condominiums-omaha-ne-5Xt8Dq/
# 44   1025.0             1213 Harney St APT 401 Omaha NE 68102                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/1213-Harney...
# 45   2250.0                     1210 Marcy Plz Omaha NE 68108                                                                                                 2  ...  https://www.zillow.com/homedetails/1210-Marcy-...
# 46   1250.0                     6805 Blondo St Omaha NE 68104                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/6805-Blondo...
# 47   1750.0               11126 Leavenworth St Omaha NE 68154                                              3  ...                                             4  ...  https://www.zillow.com/homedetails/11126-Leave...
# 48   1600.0                     1041 S 48th St Omaha NE 68106                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1041-S-48th...
# 49    950.0                    4702 Wakeley St Omaha NE 68132                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/4702-Wakele...
# 50   1750.0                      9348 Corby St Omaha NE 68134                                              4  ...                                             3  ...  https://www.zillow.com/homedetails/9348-Corby-...
# 51   1175.0                     1324 N 52nd St Omaha NE 68132                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/1324-N-52nd...
# 52   1850.0                     1720 N 59th St Omaha NE 68104                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/1720-N-59th...
# 53    705.0               1138 S 29th St APT 8 Omaha NE 68105                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/1138-S-29th...
# 54   1700.0                    5007 Pacific St Omaha NE 68106                                                                                                 4  ...  https://www.zillow.com/homedetails/5007-Pacifi...
# 55   1400.0                      619 S 19th St Omaha NE 68102                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/619-S-19th-...
# 56   1800.0                         19514 X St Omaha NE 68135                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/19514-X-St-...
# 57    900.0                       6303 Wirt St Omaha NE 68104                                              3  ...                                             2  ...  https://www.zillow.com/homedetails/6303-Wirt-S...
# 58    975.0                     1109 S 10th St Omaha NE 68108                                              1  ...                                             2  ...  https://www.zillow.com/homedetails/1109-S-10th...
# 59   1625.0              (undisclosed Address) Omaha NE 68137                                              4  ...                                             3  ...  https://www.zillow.com/homedetails/Omaha-NE-68...
# 60   1500.0                      535 N 76th St Omaha NE 68114                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/535-N-76th-...
# 61    800.0                 5007 California St Omaha NE 68132                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/5007-Califo...
# 62   1995.0                    14943 Dayton St Omaha NE 68137                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/14943-Dayto...
# 63   1795.0                      525 S 31st St Omaha NE 68105                                                                                                 4  ...  https://www.zillow.com/homedetails/525-S-31st-...
# 64    800.0                204 Paxton Ct APT 5 Omaha NE 68131                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/204-Paxton-...
# 65   1875.0                     3509 Howard St Omaha NE 68105                                              3  ...                                             5  ...  https://www.zillow.com/homedetails/3509-Howard...
# 66    950.0                      809 N 34th St Omaha NE 68131                                              3  ...                                             2  ...  https://www.zillow.com/homedetails/809-N-34th-...
# 67    800.0                     2519 S 12th St Omaha NE 68108                                              1  ...                                             2  ...  https://www.zillow.com/homedetails/2519-S-12th...
# 68   6551.0      Lyndale Apartments | 1052 S 20th St Omaha NE                                              4  ...                                                                /b/lyndale-apartments-omaha-ne-5ZRCbY/
# 69   1495.0                    2728 N 65th Ave Omaha NE 68104                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/2728-N-65th...
# 70   1675.0                      9110 Black St Omaha NE 68122                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/9110-Black-...
# 71   1050.0                     558 S 26th Ave Omaha NE 68105                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/558-S-26th-...
# 72    575.0                     135 N 43rd Ave Omaha NE 68131                                                                                                 1  ...  https://www.zillow.com/homedetails/135-N-43rd-...
# 73   1795.0                      17828 Edna St Omaha NE 68136                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/17828-Edna-...
# 74   1250.0                     1615 N 58th St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1615-N-58th...
# 75   1150.0                     213 S 26th Ave Omaha NE 68131                                              3  ...                                             2  ...  https://www.zillow.com/homedetails/213-S-26th-...
# 76   1375.0                     4105 N 91st St Omaha NE 68134                                              1  ...                                             3  ...  https://www.zillow.com/homedetails/4105-N-91st...
# 77   1500.0                     2304 N 70th St Omaha NE 68104                                              4  ...                                             3  ...  https://www.zillow.com/homedetails/2304-N-70th...
# 78   7751.0                          3323 Webster St Omaha NE                                               1 ...                                              80...                /b/Omaha-NE/41.265532-95.962664_ll/
# 79    775.0                    3325 Webster St Omaha NE 68131                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/3325-Webste...
# 80   1345.0                     4905 N 65th St Omaha NE 68104                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/4905-N-65th...
# 81   1000.0                  4314 N 52nd St #1 Omaha NE 68104                                                                                                 3  ...  https://www.zillow.com/homedetails/4314-N-52nd...
# 82    950.0            2624 N 205th St APT 3 Elkhorn NE 68022                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/2624-N-205t...
# 83   1595.0                    7122 S 176th St Omaha NE 68136                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/7122-S-176t...
# 84   1350.0                      2409 Emmet St Omaha NE 68111                                              3  ...                                             4  ...  https://www.zillow.com/homedetails/2409-Emmet-...
# 85   1000.0                  1465 S 17th St #A Omaha NE 68108                                              1  ...                                             3  ...  https://www.zillow.com/homedetails/1465-S-17th...
# 86   1150.0                 4609 Cass St APT 2 Omaha NE 68132                                              4  ...                                             2  ...  https://www.zillow.com/homedetails/4609-Cass-S...
# 87   1495.0                     15919 Gold Cir Omaha NE 68130                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/15919-Gold-...
# 88   2495.0                15222 Pepperwood Dr Omaha NE 68154                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/15222-Peppe...
# 89   1100.0                    1820 N 48th Ave Omaha NE 68104                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/1820-N-48th...
