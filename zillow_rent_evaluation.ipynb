# %%
import json
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext
# Out:
# C:\Users\14026\anaconda3\envs\dev\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %%
#create url variables for each zillow page
with requests.Session() as s:
    city = 'Omaha/' 
    
    url = 'https://www.zillow.com/homes/for_rent/'+city
    url2 = 'https://www.zillow.com/homes/for_rent/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_rent/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_rent/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_rent/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_rent/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_rent/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_rent/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_rent/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_rent/'+city+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# %%
#create the first two dataframes
df = pd.DataFrame()
df1 = pd.DataFrame()

#all for loops are pulling the specified variable using beautiful soup and inserting into said variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul",  class_="list-card-details"))
    sqft = list(soup.find_all("ul",  class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds
    df['sqft'] = sqft
    

#create empty url list
urls = []

# %%
#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df['links'] = urls
df['links'] = df['links'].astype('str')

#remove html tags
df['links'] = df['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)


for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df1['prices'] = price1
    df1['address'] = address1
    df1['beds'] = beds1
    df1['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

#remove html tags
df1['links'] = df1['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df1['links'] = df1['links'].replace('" tabindex="0"></a>', ' ', regex=True)

#append first two dataframes
df = df.append(df1, ignore_index = True) 

#create empty dataframes
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()

for i in soup2:
    soup = soup2
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul",  class_="list-card-details"))
    sqft = list(soup.find_all("ul",  class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df2['prices'] = price
    df2['address'] = address1
    df2['beds'] = beds
    df2['sqft'] = sqft

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

#remove html tags
df2['links'] = df2['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df2['links'] = df2['links'].replace('" tabindex="0"></a>', ' ', regex=True)

    
for i in soup3:
    soup = soup3
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df3['prices'] = price1
    df3['address'] = address1
    df3['beds'] = beds
    df3['sqft'] = sqft

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

#remove html tags
df3['links'] = df3['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df3['links'] = df3['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup4:
    soup = soup4
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df4['prices'] = price1
    df4['address'] = address1
    df4['beds'] = beds
    df4['sqft'] = sqft1
    
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup4.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df4['links'] = urls
df4['links'] = df4['links'].astype('str')

#remove html tags
df4['links'] = df4['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df4['links'] = df4['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup5:
    soup = soup5
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df5['prices'] = price1
    df5['address'] = address1
    df5['beds'] = beds
    df5['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup5.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df5['links'] = urls
df5['links'] = df5['links'].astype('str')

#remove html tags
df5['links'] = df5['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df5['links'] = df5['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup6:
    soup = soup6
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df6['prices'] = price1
    df6['address'] = address1
    df6['beds'] = beds
    df6['sqft'] = sqft1
    
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup6.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df6['links'] = urls
df6['links'] = df6['links'].astype('str')

#remove html tags
df6['links'] = df6['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df6['links'] = df6['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup7:
    soup = soup7
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df7['prices'] = price1
    df7['address'] = address1
    df7['beds'] = beds
    df7['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup7.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df7['links'] = urls
df7['links'] = df7['links'].astype('str')

#remove html tags
df7['links'] = df7['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df7['links'] = df7['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup8:
    soup = soup8
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df8['prices'] = price1
    df8['address'] = address1
    df8['beds'] = beds
    df8['sqft'] = sqft1
    
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup8.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)

#import urls into a links column
df8['links'] = urls
df8['links'] = df8['links'].astype('str')

#remove html tags
df8['links'] = df8['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df8['links'] = df8['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup9:
    soup = soup9
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    sqft1 = list(soup.find_all("ul",  class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df9['prices'] = price1
    df9['address'] = address1
    df9['beds'] = beds
    df9['sqft'] = sqft1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup9.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href:
        addresses = href.get('href')
        urls.append(addresses)
    
#import urls into a links column
df9['links'] = urls
df9['links'] = df9['links'].astype('str')

#remove html tags
df9['links'] = df9['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
df9['links'] = df9['links'].replace('" tabindex="0"></a>', ' ', regex=True)

df = df.append(df2, ignore_index = True) 
df = df.append(df3, ignore_index = True) 
df = df.append(df4, ignore_index = True) 
df = df.append(df5, ignore_index = True) 
df = df.append(df6, ignore_index = True) 
df = df.append(df7, ignore_index = True) 
df = df.append(df8, ignore_index = True) 
df = df.append(df9, ignore_index = True) 

#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')
df['sqft'] = df['sqft'].astype('str')

#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')

#need to figure out correct html to add to this code from zillow browser
#remove html tags from beds column
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].str.replace(r'\D', ' ', regex=True)
df['sqft'] = df['sqft'].replace('Studio</li><li>', '0 ', regex=True)
df['sqft'] = df['sqft'].str.replace(r'\D', ' ', regex=True)


#split beds column into beds, bath and sqft
#will need to concatenate and split up columns after everything is pulled into data frame

#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

#drop nulls
df = df[(df['prices'] != '') & (df['prices']!= ' ')]

#convert column to float
df['prices'] = df['prices'].astype('float')


#remove spaces from link column
df['links'] = df.links.str.replace(' ','')

print('The column datatypes are:')
print(df.dtypes)
print('The dataframe shape is:', df.shape)

#re arrange the data frame and include sq  - make sure the dataframe has correct vallues
#will need to split zip code into its own column
#find out how to extract zillow html and put it into notebook

df
# Out:
# The column datatypes are:
# prices     float64
# address     object
# beds        object
# sqft        object
# links       object
# dtype: object
# The dataframe shape is: (90, 5)
#      prices                                            address                                               beds                                               sqft                                              links
# 0    1650.0                    12823 Valley St Omaha NE 68144                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/12823-Valle...
# 1     750.0                       4816 Cass St Omaha NE 68132                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/4816-Cass-S...
# 2    2500.0                      404 N 40th St Omaha NE 68131                                              5  ...                                             5  ...  https://www.zillow.com/homedetails/404-N-40th-...
# 3    1800.0                    6718 S 152nd St Omaha NE 68137                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/6718-S-152n...
# 4    1750.0                      9147 Scott St Omaha NE 68122                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/9147-Scott-...
# 5    1500.0                     1520 N 84th St Omaha NE 68114                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1520-N-84th...
# 6    2100.0                  3818 S 189th St Elkhorn NE 68130                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/3818-S-189t...
# 7     490.0                    2415 F St APT 7 Omaha NE 68107                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/2415-F-St-A...
# 8     765.0                   2613 Patrick Ave Omaha NE 68111                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2613-Patric...
# 9    8201.0       Briarwood by Broadmoor | 9434 U Ct Omaha NE                                              3  ...                                             3  ...         /b/briarwood-by-broadmoor-omaha-ne-5XtP5G/
# 10    980.0               7515 Howard St #1106 Omaha NE 68114                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/7515-Howard...
# 11   1025.0             1213 Harney St APT 401 Omaha NE 68102                                              5  ...                                             5  ...  https://www.zillow.com/homedetails/1213-Harney...
# 12   9651.0   Park Place Apartments | 12115 William Plz Oma...                                             3  ...                                             3  ...          /b/park-place-apartments-omaha-ne-5Yy8PJ/
# 13   8651.0             Park West | 10901 Jaynes Plz Omaha NE                                              3  ...                                             3  ...                      /b/park-west-omaha-ne-5YyCKM/
# 14    950.0     Broadmoor Hills | 18510 Capitol Ct Elkhorn NE                                              3  ...                                             3  ...              /b/broadmoor-hills-elkhorn-ne-B5p73S/
# 15    937.0        Legacy Commons | 17011 Wright Plz Omaha NE                                              3  ...                                             3  ...                 /b/legacy-commons-omaha-ne-5Xrv3W/
# 16   1300.0                     6010 Seward St Omaha NE 68104                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/6010-Seward...
# 17  15852.0        Lakeside Hills | 17040 Frances St Omaha NE                                              3  ...                                             3  ...                 /b/lakeside-hills-omaha-ne-5Xt98d/
# 18   6851.0       Briarwood by Broadmoor | 9434 U Ct Omaha NE                                               84...                                              84...        /b/willow-creek-apartments-omaha-ne-5Xt9C8/
# 19    850.0               7515 Howard St #1106 Omaha NE 68114                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/734-S-50th-...
# 20    730.0             1213 Harney St APT 401 Omaha NE 68102                                               78...                                              78...                /b/camelot-village-omaha-ne-5Xt4F9/
# 21  10451.0   Park Place Apartments | 12115 William Plz Oma...                                              1 ...                                              1 ...    /b/wyndham-villas-by-broadmoor-omaha-ne-5Yy8NG/
# 22   1210.0             Park West | 10901 Jaynes Plz Omaha NE                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/617-S-31st-...
# 23   8501.0     Broadmoor Hills | 18510 Capitol Ct Elkhorn NE                                               1 ...                                              1 ...            /b/raintree-apartments-omaha-ne-5XrtT4/
# 24  11051.0        Legacy Commons | 17011 Wright Plz Omaha NE                                               1 ...                                              1 ...   /b/the-villas-at-falling-waters-omaha-ne-BDWBGs/
# 25   9951.0                     6010 Seward St Omaha NE 68104                                               1 ...                                              1 ...                       /b/the-wire-omaha-ne-5hJ8zs/
# 26   8051.0        Lakeside Hills | 17040 Frances St Omaha NE                                               1 ...                                              1 ...        /b/the-biltmore-apartments-omaha-ne-5XmzNg/
# 27   6501.0    ViewHouse Apartments | 1111 N 27th St Omaha NE                                               84...                                              84...           /b/viewhouse-apartments-omaha-ne-5Xt8RW/
# 28  14402.0       TipTop Apartments | 1524 Cuming St Omaha NE                                              2  ...                                             2  ...              /b/tiptop-apartments-omaha-ne-5Xt4Z9/
# 29   9451.0   Eagle Run Apartments | 3203 N 121st Plz Omaha...                                              78...                                              78...           /b/eagle-run-apartments-omaha-ne-5hJ8zn/
# 30  10151.0                    Slate | 119 N 19th St Omaha NE                                               1 ...                                              1 ...                          /b/slate-omaha-ne-5XqbF9/
# 31   1800.0                  1821 N 207th St Elkhorn NE 68022                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1821-N-207t...
# 32   2400.0                      17218 Pine St Omaha NE 68130                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/17218-Pine-...
# 33   1800.0                   16406 Camden Ave Omaha NE 68116                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/16406-Camde...
# 34   2750.0                         18905 B St Omaha NE 68130                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/18905-B-St-...
# 35   1825.0                       8906 Read St Omaha NE 68122                                               1 ...                                              1 ...  https://www.zillow.com/homedetails/8906-Read-S...
# 36   1750.0                      9348 Corby St Omaha NE 68134                                               84...                                             3  ...  https://www.zillow.com/homedetails/9348-Corby-...
# 37   1175.0                     1324 N 52nd St Omaha NE 68132                                              2  ...                                             3  ...  https://www.zillow.com/homedetails/1324-N-52nd...
# 38   1450.0                    2886 Bauman Ave Omaha NE 68112                                               78...                                             4  ...  https://www.zillow.com/homedetails/2886-Bauman...
# 39   1850.0                     1720 N 59th St Omaha NE 68104                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/1720-N-59th...
# 40    705.0               1138 S 29th St APT 8 Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1138-S-29th...
# 41    675.0                      145 N 34th St Omaha NE 68131                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/145-N-34th-...
# 42   1900.0               16144 Cottonwood Ave Omaha NE 68136                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/16144-Cotto...
# 43   1550.0                     4320 Drexel St Omaha NE 68107                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/4320-Drexel...
# 44   1450.0                     2821 N 56th St Omaha NE 68104                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/2821-N-56th...
# 45   2000.0                   17477 Riviera Dr Omaha NE 68136                                               84...                                             3  ...  https://www.zillow.com/homedetails/17477-Rivie...
# 46   1300.0                     1101 S 63rd St Omaha NE 68106                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/1101-S-63rd...
# 47    750.0                     2626 Dewey Ave Omaha NE 68105                                               78...                                             1  ...  https://www.zillow.com/homedetails/2626-Dewey-...
# 48   1700.0                    5007 Pacific St Omaha NE 68106                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/5007-Pacifi...
# 49   1100.0                   5235 Magnolia St Omaha NE 68137                                              1  ...                                             4  ...  https://www.zillow.com/homedetails/5235-Magnol...
# 50   1550.0                       5838 Ohio St Omaha NE 68104                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/5838-Ohio-S...
# 51   1400.0                      619 S 19th St Omaha NE 68102                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/619-S-19th-...
# 52   2200.0                 3402 California St Omaha NE 68131                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/3402-Califo...
# 53   1350.0                  3205 Lincoln Blvd Omaha NE 68131                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/3205-Lincol...
# 54   1650.0                     6339 Pierce St Omaha NE 68106                                               84...                                             2  ...  https://www.zillow.com/homedetails/6339-Pierce...
# 55   1650.0             926 S 153rd Terrace Ct Omaha NE 68154                                              2  ...                                             3  ...  https://www.zillow.com/homedetails/926-S-153rd...
# 56   1700.0                 16278 Jefferson St Omaha NE 68135                                               78...                                             3  ...  https://www.zillow.com/homedetails/16278-Jeffe...
# 57   1649.0                    8612 S 143rd St Omaha NE 68138                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/8612-S-143r...
# 58   1095.0                      4149 Grant St Omaha NE 68111                                              1  ...                                             3  ...  https://www.zillow.com/homedetails/4149-Grant-...
# 59   1850.0                         19354 X St Omaha NE 68135                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/19354-X-St-...
# 60   1650.0                    2202 N 166th St Omaha NE 68116                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/2202-N-166t...
# 61   1500.0                     1820 N 48th St Omaha NE 68104                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/1820-N-48th...
# 62   1700.0                     19627 Gail Ave Omaha NE 68135                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/19627-Gail-...
# 63   6912.0           Lofts on 24th | 3101 S 24th St Omaha NE                                               84...                                              75...                  /b/lofts-on-24th-omaha-ne-9SWTVf/
# 64   2800.0                  5026 N 209th St Elkhorn NE 68022                                              2  ...                                             4  ...  https://www.zillow.com/homedetails/5026-N-209t...
# 65   1700.0                    3316 S 117th St Omaha NE 68144                                               78...                                             3  ...  https://www.zillow.com/homedetails/3316-S-117t...
# 66    700.0          3304 Burt Street | 3304 Burt St Omaha NE                                               1 ...                                              73...               /b/3304-burt-street-omaha-ne-5YNgpP/
# 67   1750.0                    7513 S 134th St Omaha NE 68138                                              1  ...                                             3  ...  https://www.zillow.com/homedetails/7513-S-134t...
# 68   5951.0                            540 S 30th St Omaha NE                                               1 ...                                                                     /b/540-s-30th-st-omaha-ne-5XkZcP/
# 69    900.0        1319 Leavenworth St APT 204 Omaha NE 68102                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/1319-Leaven...
# 70   1295.0                     7452 Rogers Rd Omaha NE 68124                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/7452-Rogers...
# 71    675.0                   4727 Cass St #11 Omaha NE 68132                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/4727-Cass-S...
# 72   1550.0                     17712 Margo St Omaha NE 68136                                               84...                                             3  ...  https://www.zillow.com/homedetails/17712-Margo...
# 73    895.0                      12230 Anne St Omaha NE 68137                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/12230-Anne-...
# 74   1125.0                     3417 Seward St Omaha NE 68111                                               78...                                             3  ...  https://www.zillow.com/homedetails/3417-Seward...
# 75   6952.0   7306-7316 Maple St | 7306-7316 Maple St Omaha...                                              1 ...                                                                /b/7306-7316-maple-st-omaha-ne-BMXHCk/
# 76   1995.0                      5111 Dodge St Omaha NE 68132                                              1  ...                                             3  ...  https://www.zillow.com/homedetails/5111-Dodge-...
# 77   1050.0                     5250 S 48th St Omaha NE 68117                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/5250-S-48th...
# 78    800.0                   211 Walnut St #1 Omaha NE 68108                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/211-Walnut-...
# 79   1300.0                          1608 Z St Omaha NE 68107                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/1608-Z-St-O...
# 80   1650.0                    10910 Harney St Omaha NE 68154                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/10910-Harne...
# 81   1850.0                       5217 Pine St Omaha NE 68106                                               84...                                             3  ...  https://www.zillow.com/homedetails/5217-Pine-S...
# 82   2200.0                      123 S 54th St Omaha NE 68132                                              2  ...                                             4  ...  https://www.zillow.com/homedetails/123-S-54th-...
# 83    945.0                   6522 Hamilton St Omaha NE 68132                                               78...                                             2  ...  https://www.zillow.com/homedetails/6522-Hamilt...
# 84   8051.0    907 South 25th Street | 907 S 25th St Omaha NE                                               1 ...                                                             /b/907-south-25th-street-omaha-ne-9SWNwB/
# 85   8351.0       534-542 Park Avenue | 534 Park Ave Omaha NE                                              1  ...                                                               /b/534-542-park-avenue-omaha-ne-9JdGkn/
# 86   1877.0                         18681 U St Omaha NE 68135                                               1 ...                                             4  ...  https://www.zillow.com/homedetails/18681-U-St-...
# 87   1900.0                5629 Bay Meadows Rd Omaha NE 68127                                               1 ...                                             3  ...  https://www.zillow.com/homedetails/5629-Bay-Me...
# 88    650.0                 5005 California St Omaha NE 68132                                               1 ...                                             1  ...  https://www.zillow.com/homedetails/5005-Califo...
# 89   1395.0            3311 S 54th St #3827250 Omaha NE 68106                                               1 ...                                             2  ...  https://www.zillow.com/homedetails/3311-S-54th...
