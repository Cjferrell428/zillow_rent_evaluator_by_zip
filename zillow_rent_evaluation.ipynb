# %% [markdown]
# ## Base Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ## Notebook and Request Header Settings

# %%
# set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

# %% [markdown]
# ## Helper functions for Creating Soups

# %%
def build_soups(url):
    """
    Builds BeautifulSoup objects for each page of the Zillow search results.
    """
    response = requests.get(url, headers=req_headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %% [markdown]
# ## Grab/Create all Soups

# %%
base_url = 'https://www.zillow.com/homes/for_rent/'
page_max_range = 10
city = 'Omaha'
soups = []

for i in range(1, page_max_range):
    url = f'{base_url}{city}/{str(i)}_p/'
    soups.append(build_soups(url))

# %% [markdown]
# ## Grab Data from All Soups and Create Huge Dataframe

# %%
def grab_soup_data(soups):
    """
    Grabs all the data from the soup objects and puts it into a list.
    """
    soup_data = []
    for soup in soups:
        # all for loops are pulling the specified variable using beautiful soup and inserting into said variable
        df = pd.DataFrame(
            columns=['prices', 'address', 'beds', 'sqft', 'links'])

        for i in soup:
            address = soup.find_all(class_='list-card-addr')
            price = list(soup.find_all(class_='list-card-price'))
            beds = list(soup.find_all("ul",  class_="list-card-details"))
            sqft = list(soup.find_all("ul",  class_="list-card-details"))
            details = soup.find_all('div', {'class': 'list-card-details'})
            home_type = soup.find_all('div', {'class': 'list-card-footer'})
            last_updated = soup.find_all('div', {'class': 'list-card-top'})
            brokerage = list(soup.find_all(
                class_='list-card-brokerage list-card-img-overlay', text=True))
            link = soup.find_all(class_='list-card-link')

            # create dataframe columns out of variables
            df['prices'] = price
            df['address'] = address
            df['beds'] = beds
            df['sqft'] = sqft

        # create empty url list
        urls = []

        # loop through url, pull the href and strip out the address tag
        for link in soup.find_all("article"):
            href = link.find('a', class_="list-card-link")
            if href:
                addresses = href.get('href')
                urls.append(addresses)

        # import urls into a links column
        df['links'] = urls
        df['links'] = df['links'].astype('str')

        # remove html tags
        df['links'] = df['links'].replace(
            '<a class="list-card-link" href="', ' ', regex=True)
        df['links'] = df['links'].replace(
            '" tabindex="0"></a>', ' ', regex=True)
        soup_data.append(df)
    return soup_data

df = pd.concat(grab_soup_data(soups))

# %% [markdown]
# ## Cleanup the Huge Dataframe

# %%
#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')
df['sqft'] = df['sqft'].astype('str')

#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')

#need to figure out correct html to add to this code from zillow browser
#remove html tags from beds column
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].str.replace(r'\D', ' ', regex=True)
df['sqft'] = df['sqft'].replace('Studio</li><li>', '0 ', regex=True)
df['sqft'] = df['sqft'].str.replace(r'\D', ' ', regex=True)


#split beds column into beds, bath and sqft
#will need to concatenate and split up columns after everything is pulled into data frame

#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

#drop nulls
df = df[(df['prices'] != '') & (df['prices']!= ' ')]

#convert column to float
df['prices'] = df['prices'].astype('float')


#remove spaces from link column
df['links'] = df.links.str.replace(' ','')

print('The column datatypes are:')
print(df.dtypes)
print('The dataframe shape is:', df.shape)

#re arrange the data frame and include sq  - make sure the dataframe has correct vallues
#will need to split zip code into its own column
#find out how to extract zillow html and put it into notebook

df
# Out:
# The column datatypes are:
# prices     float64
# address     object
# beds        object
# sqft        object
# links       object
# dtype: object
# The dataframe shape is: (81, 5)
# /Users/n8patteson/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   if sys.path[0] == '':
#     prices                                            address                                               beds                                               sqft                                              links
# 0   1500.0                     2510 N 64th St Omaha NE 68104                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2510-N-64th...
# 1   1600.0                   2329 N 143rd Ave Omaha NE 68164                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2329-N-143r...
# 2    970.0   Broadmoor at Aksarben Village | 2225 S 64th P...                                              1 ...                                              1 ...  /b/broadmoor-at-aksarben-village-omaha-ne-5XtPhk/
# 3   1125.0           The Duke Omaha | 201 N 46th St Omaha NE                                               1 ...                                              1 ...                 /b/the-duke-omaha-omaha-ne-BLzSVn/
# 4   1110.0               The Conrad | 3601 Jones St Omaha NE                                               1 ...                                              1 ...                     /b/the-conrad-omaha-ne-9WHB3w/
# 5   9541.0        Briar Hills | 17010 Hawthorne Plz Omaha NE                                               1 ...                                              1 ...                    /b/briar-hills-omaha-ne-5Xs6sD/
# 6   2493.0            909 Capitol Ave APT 401 Omaha NE 68102                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/909-Capitol...
# 7   9951.0   Wyndham Hill by Broadmoor | 9226 Burt St Omah...                                              1 ...                                              1 ...      /b/wyndham-hill-by-broadmoor-omaha-ne-5XtP4L/
# 8   1250.0                 3412 Dodge St #106 Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/3412-Dodge-...
# 0  10001.0                  Jones13 | 1301 Jones St Omaha NE                                                                                                                               /b/jones13-omaha-ne-5ZLdYZ/
# 1    980.0               7515 Howard St #1106 Omaha NE 68114                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/7515-Howard...
# 2    850.0                 1427 1/2 S 14th St Omaha NE 68108                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/1427-1-2-S-...
# 3   1210.0              617 S 31st St APT 401 Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/617-S-31st-...
# 4   9651.0   Park Place Apartments | 12115 William Plz Oma...                                              1 ...                                              1 ...          /b/park-place-apartments-omaha-ne-5Yy8PJ/
# 5  10131.0   Autumn Grove Apartments | 5380 S 156th St Oma...                                              1 ...                                              1 ...        /b/autumn-grove-apartments-omaha-ne-BKzzfc/
# 6   7501.0         Kensington Tower | 505 S 16th St Omaha NE                                                                                                                      /b/kensington-tower-omaha-ne-5XnQKq/
# 7   8551.0      The Bank Apartments | 206 S 19th St Omaha NE                                               1 ...                                              1 ...            /b/the-bank-apartments-omaha-ne-5Xt4ZT/
# 8  11251.0   Midtown Crossing Apartments | 233 S 33rd St O...                                              1 ...                                              1 ...    /b/midtown-crossing-apartments-omaha-ne-5Xt4dv/
# 0   1115.0              15702 Fowler Plz #385 Omaha NE 68116                                              1  ...                                             1  ...  https://www.zillow.com/homedetails
                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1041-S-48th...
# 5    950.0                    4702 Wakeley St Omaha NE 68132                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/4702-Wakele...
# 6   1750.0                      9348 Corby St Omaha NE 68134                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/9348-Corby-...
# 7   1175.0                     1324 N 52nd St Omaha NE 68132                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1324-N-52nd...
# 8   1850.0                     1720 N 59th St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1720-N-59th...
# 0    750.0                     2626 Dewey Ave Omaha NE 68105                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/2626-Dewey-...
# 1   1700.0                    5007 Pacific St Omaha NE 68106                                              4  ...                                             4  ...  https://www.zillow.com/homedetails/5007-Pacifi...
# 2   1400.0                      619 S 19th St Omaha NE 68102                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/619-S-19th-...
# 3    960.0                       4149 Lake St Omaha NE 68111                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/4149-Lake-S...
# 4  13001.0                           1105 Harney St Omaha NE                                               1 ...                                              1 ...             /b/1105-harney-street-omaha-ne-5Xxd8M/
# 5   1750.0          4111 N Hws Cleveland Blvd Omaha NE 68116                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/4111-N-Hws-...
# 6   2195.0                   4360 S 153rd Cir Omaha NE 68137                                              4  ...                                             4  ...  https://www.zillow.com/homedetails/4360-S-153r...
# 7   2350.0                   17024 Shirley St Omaha NE 68130                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/17024-Shirl...
# 8   1650.0                    8132 S 154th St Omaha NE 68138                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/8132-S-154t...
# 0    925.0                      7305 Ames Cir Omaha NE 68134                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/7305-Ames-C...
# 1   1795.0                      525 S 31st St Omaha NE 68105                                              4  ...                                             4  ...  https://www.zillow.com/homedetails/525-S-31st-...
# 2    800.0                204 Paxton Ct APT 5 Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/204-Paxton-...
# 3   1875.0                     3509 Howard St Omaha NE 68105                                              5  ...                                             5  ...  https://www.zillow.com/homedetails/3509-Howard...
# 4    950.0                      809 N 34th St Omaha NE 68131                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/809-N-34th-...
# 5    800.0                     2519 S 12th St Omaha NE 68108                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/2519-S-12th...
# 6   6551.0      Lyndale Apartments | 1052 S 20th St Omaha NE                                                                                                                    /b/lyndale-apartments-omaha-ne-5ZRCbY/
# 7   1495.0                    2728 N 65th Ave Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2728-N-65th...
# 8   1675.0                      9110 Black St Omaha NE 68122                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/9110-Black-...
# 0    575.0                     135 N 43rd Ave Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/135-N-43rd-...
# 1   1795.0                      17828 Edna St Omaha NE 68136                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/17828-Edna-...
# 2   1250.0                     1615 N 58th St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/1615-N-58th...
# 3   1150.0                     213 S 26th Ave Omaha NE 68131                                              2  ...                                             2  ...  https://www.zillow.com/homedetails/213-S-26th-...
# 4   1375.0                     4105 N 91st St Omaha NE 68134                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/4105-N-91st...
# 5   1500.0                     2304 N 70th St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/2304-N-70th...
# 6   7751.0                          3323 Webster St Omaha NE                                               80...                                              80...                /b/Omaha-NE/41.265532-95.962664_ll/
# 7    775.0                    3325 Webster St Omaha NE 68131                                              1  ...                                             1  ...  https://www.zillow.com/homedetails/3325-Webste...
# 8   1345.0                     4905 N 65th St Omaha NE 68104                                              3  ...                                             3  ...  https://www.zillow.com/homedetails/4905-N-65th...
